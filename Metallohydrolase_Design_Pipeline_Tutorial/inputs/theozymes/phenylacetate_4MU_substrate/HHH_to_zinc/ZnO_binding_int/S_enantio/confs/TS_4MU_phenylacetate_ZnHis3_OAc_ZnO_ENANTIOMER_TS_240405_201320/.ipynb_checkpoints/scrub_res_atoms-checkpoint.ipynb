# %%
xyzf = open("saved_xyz.xyz", "r").readlines()

# %%
xyzs = []
for l in xyzf:
    if l == "74\n":
        xyzs.append([])
    xyzs[-1].append(l)

# %%
len(xyzs)
# Out:
# 10

# %%
keep_atom_ranges = [[1, 18], [54, 74]]
xyz_cropped = []
for xyz in xyzs:
    xyz_cropped.append([xyz[1]])
    for rng in keep_atom_ranges:
        for n in range(rng[0], rng[1]+1):
            xyz_cropped[-1].append(xyz[n+1])

# %%
xyz_cropped[0]
# Out:
# ['TS_4MU_phenylacetate_ZnHis3_OAc_ZnO_ENANTIOMER_TS_0.xyz -124.326193369883\n',
#  'Zn        -0.43339       -0.01897        0.63021\n',
#  'O         -1.24491        0.19684       -1.18461\n',
#  'C         -1.02866       -1.48548       -1.68499\n',
#  'O         -0.77399       -2.06346       -0.60513\n',
#  'O          0.02644       -1.32425       -2.65797\n',
#  'H         -0.75129        0.80173       -1.78022\n',
#  'C          1.30365       -1.28911       -2.14903\n',
#  'C          1.89253       -0.05734       -1.88004\n',
#  'C          2.00002       -2.48288       -1.91289\n',
#  'C          3.15211       -0.03351       -1.28857\n',
#  'C          3.26982       -2.43742       -1.36232\n',
#  'C          3.86933       -1.21082       -1.01307\n',
#  'H          1.37510        0.87285       -2.08250\n',
#  'H          1.52122       -3.42713       -2.14338\n',
#  'H          3.79863       -3.36261       -1.16461\n',
#  'C         -2.30107       -1.74443       -2.49082\n',
#  'H         -2.31199       -1.07014       -3.35037\n',
#  'H         -2.20331       -2.76657       -2.87762\n',
#  'O          3.64177        1.19995       -0.95439\n',
#  'C          4.85751        1.35959       -0.29854\n',
#  'O          5.18088        2.49632       -0.00907\n',
#  'C          5.60661        0.15182       -0.02728\n',
#  'H          6.55711        0.29427        0.47356\n',
#  'C          5.15763       -1.08879       -0.35917\n',
#  'C          5.95821       -2.31800       -0.04216\n',
#  'H          6.18219       -2.88347       -0.95397\n',
#  'H          6.89953       -2.05833        0.44663\n',
#  'H          5.39473       -2.98500        0.62034\n',
#  'C         -3.56964       -1.60944       -1.68779\n',
#  'C         -4.35498       -0.45324       -1.78364\n',
#  'C         -3.99142       -2.63692       -0.83446\n',
#  'C         -5.53501       -0.32560       -1.04737\n',
#  'C         -5.16904       -2.51359       -0.09525\n',
#  'C         -5.94683       -1.35821       -0.20079\n',
#  'H         -4.04024        0.35139       -2.44225\n',
#  'H         -3.38991       -3.53734       -0.75045\n',
#  'H         -6.13194        0.57762       -1.13722\n',
#  'H         -5.47954       -3.32015        0.56291\n',
#  'H         -6.86471       -1.26249        0.37202\n']

# %%
with open("saved_xyz_cropped.xyz", "w") as file:
    for xyz in xyz_cropped:
        file.write(f"{len(xyz)-1}\n")
        for l in xyz:
            file.write(l)
