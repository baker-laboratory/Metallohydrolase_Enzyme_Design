# %%
xyzf = open("saved_xyz.xyz", "r").readlines()

# %%
xyzs = []
for l in xyzf:
    if l == "74\n":
        xyzs.append([])
    xyzs[-1].append(l)

# %%
len(xyzs)
# Out:
# 10

# %%
keep_atom_ranges = [[1, 18], [54, 74]]
xyz_cropped = []
for xyz in xyzs:
    xyz_cropped.append([xyz[1]])
    for rng in keep_atom_ranges:
        for n in range(rng[0], rng[1]+1):
            xyz_cropped[-1].append(xyz[n+1])

# %%
xyz_cropped[0]
# Out:
# ['TS_4MU_phenylacetate_ZnHis3_OAc_ZnO_0.xyz -124.331529960375\n',
#  'Zn        -0.90305       -0.45656       -0.41943\n',
#  'O         -0.74126        0.95523        1.03015\n',
#  'C         -0.54809       -0.26412        2.32590\n',
#  'O         -0.43136       -1.32092        1.65603\n',
#  'O          0.57865        0.27093        2.99943\n',
#  'H         -1.53744        1.51957        1.09664\n',
#  'C          1.77563        0.31468        2.32700\n',
#  'C          2.36987       -0.81849        1.77829\n',
#  'C          2.40068        1.56917        2.23581\n',
#  'C          3.57305       -0.66742        1.09526\n',
#  'C          3.61606        1.68958        1.58319\n',
#  'C          4.23017        0.57197        0.98394\n',
#  'H          1.89314       -1.78478        1.83693\n',
#  'H          1.90917        2.43091        2.67278\n',
#  'H          4.09091        2.66161        1.51406\n',
#  'C         -1.76340       -0.00753        3.22151\n',
#  'H         -1.70104       -0.75303        4.02445\n',
#  'H         -1.66618        0.97873        3.68141\n',
#  'O          4.07771       -1.79686        0.50970\n',
#  'C          5.20374       -1.76609       -0.29422\n',
#  'O          5.48821       -2.79509       -0.88545\n',
#  'C          5.92012       -0.51225       -0.36040\n',
#  'H          6.82937       -0.52116       -0.95020\n',
#  'C          5.47157        0.62428        0.23985\n',
#  'C          6.22167        1.91862        0.11454\n',
#  'H          6.48030        2.31744        1.10206\n',
#  'H          7.14146        1.78480       -0.45881\n',
#  'H          5.60675        2.67471       -0.38777\n',
#  'C         -3.07198       -0.12980        2.48014\n',
#  'C         -3.84974        1.00592        2.22084\n',
#  'C         -3.51060       -1.37066        1.99842\n',
#  'C         -5.03993        0.90700        1.49558\n',
#  'C         -4.69011       -1.47145        1.26155\n',
#  'C         -5.46125       -0.33277        1.00929\n',
#  'H         -3.52234        1.97505        2.58974\n',
#  'H         -2.91339       -2.25487        2.18723\n',
#  'H         -5.63199        1.79782        1.30637\n',
#  'H         -5.00565       -2.43981        0.88353\n',
#  'H         -6.38294       -0.41153        0.44000\n']

# %%
with open("saved_xyz_cropped.xyz", "w") as file:
    for xyz in xyz_cropped:
        file.write(f"{len(xyz)-1}\n")
        for l in xyz:
            file.write(l)
