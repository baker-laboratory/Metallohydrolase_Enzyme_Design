# %%
xyzf = open("saved_xyz.xyz", "r").readlines()

# %%
xyzs = []
for l in xyzf:
    if l == "70\n":
        xyzs.append([])
    xyzs[-1].append(l)

# %%
len(xyzs)
# Out:
# 15

# %%
keep_atom_ranges = [[1, 18], [54, 70]]
xyz_cropped = []
for xyz in xyzs:
    xyz_cropped.append([xyz[1]])
    for rng in keep_atom_ranges:
        for n in range(rng[0], rng[1]+1):
            xyz_cropped[-1].append(xyz[n+1])

# %%
xyz_cropped[0]
# Out:
# ['TS_4MU_butyrate_ZnHis3_OAc_ZnO_0.xyz -115.775345501971\n',
#  'Zn        -1.28331       -0.47768       -0.28628\n',
#  'O         -0.99808        0.95759        1.12582\n',
#  'C         -0.80714       -0.24738        2.42271\n',
#  'O         -0.73662       -1.31305        1.75210\n',
#  'O          0.36270        0.25835        3.05357\n',
#  'H         -1.72627        1.60387        1.22506\n',
#  'C          1.52533        0.29840        2.32674\n',
#  'C          2.07747       -0.83319        1.73206\n',
#  'C          2.16329        1.54606        2.22334\n',
#  'C          3.24677       -0.68647        0.99181\n',
#  'C          3.34410        1.66238        1.50988\n',
#  'C          3.91202        0.54684        0.86248\n',
#  'H          1.59209       -1.79449        1.80079\n',
#  'H          1.70635        2.40676        2.69837\n',
#  'H          3.82691        2.62973        1.43062\n',
#  'C         -1.97385        0.03163        3.35824\n',
#  'H         -1.78811       -0.56780        4.26028\n',
#  'H         -1.94953        1.08147        3.66836\n',
#  'C         -3.33560       -0.34210        2.76914\n',
#  'H         -3.52600        0.25776        1.87008\n',
#  'H         -3.30733       -1.38638        2.44040\n',
#  'C         -4.47476       -0.13443        3.76938\n',
#  'H         -4.53454        0.91257        4.09004\n',
#  'H         -4.32907       -0.74928        4.66574\n',
#  'H         -5.44011       -0.40631        3.32854\n',
#  'O          3.70963       -1.81423        0.36970\n',
#  'C          4.79103       -1.78491       -0.49268\n',
#  'O          5.03031       -2.80925       -1.11239\n',
#  'C          5.51784       -0.53877       -0.58049\n',
#  'H          6.39504       -0.54971       -1.21690\n',
#  'C          5.11382        0.59498        0.05622\n',
#  'C          5.87231        1.88232       -0.09000\n',
#  'H          6.18801        2.26242        0.88832\n',
#  'H          6.75874        1.74688       -0.71336\n',
#  'H          5.24124        2.65358       -0.54712\n']

# %%
with open("saved_xyz_cropped.xyz", "w") as file:
    for xyz in xyz_cropped:
        file.write(f"{len(xyz)-1}\n")
        for l in xyz:
            file.write(l)
